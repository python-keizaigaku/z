# %% [markdown]
# # 第11章　Pandas：より詳細な説明

# %% [markdown]
# ## はじめに

# %%
# %pip install -q py4macro
import pandas as pd
import py4macro
import random
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 42.5 MB/s eta 0:00:00

# %% [markdown]
# ## データフレームとシリーズの構成要素

# %% [markdown]
# ### データフレーム

# %% [markdown]
# コード11.2.1

# %%
random.seed(123)
n = 5
dic = {
    "C0":[random.randint(0,50)
          for _ in range(n)],
    "C1":[random.gauss()
          for _ in range(n)],
    "C2":["a", "b", "c", "d", "e"],
    "C3":["R"+str(i)
          for i in range(n)]
}
df0 = pd.DataFrame(dic)
df0
# Out:
#    C0        C1 C2  C3
# 0   3 -0.198260  a  R0
# 1  17  1.899273  b  R1
# 2   5  0.689624  c  R2
# 3  49 -0.691135  d  R3
# 4  26 -0.843840  e  R4

# %% [markdown]
# コード11.2.2

# %%
df0 = df0.set_index("C3")
df0
# Out:
#     C0        C1 C2
# C3
# R0   3 -0.198260  a
# R1  17  1.899273  b
# R2   5  0.689624  c
# R3  49 -0.691135  d
# R4  26 -0.843840  e

# %% [markdown]
# コード11.2.3

# %%
df0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, R0 to R4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   C0      5 non-null      int64
#  1   C1      5 non-null      float64
#  2   C2      5 non-null      object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 160.0+ bytes

# %% [markdown]
# コード11.2.4

# %%
df0[["C0", "C1"]].describe()
# Out:
#               C0        C1
# count   5.000000  5.000000
# mean   20.000000  0.171132
# std    18.708287  1.136379
# min     3.000000 -0.843840
# 25%     5.000000 -0.691135
# 50%    17.000000 -0.198260
# 75%    26.000000  0.689624
# max    49.000000  1.899273

# %% [markdown]
# コード11.2.5

# %%
df0.columns
# Out:
# Index(['C0', 'C1', 'C2'], dtype='object')

# %% [markdown]
# コード11.2.6

# %%
df0.index
# Out:
# Index(['R0', 'R1', 'R2', 'R3', 'R4'], dtype='object', name='C3')

# %% [markdown]
# コード11.2.7

# %%
df0.to_numpy()
# Out:
# array([[3, -0.198260084964999, 'a'],
#        [17, 1.8992726922410839, 'b'],
#        [5, 0.6896236279027714, 'c'],
#        [49, -0.6911353794461756, 'd'],
#        [26, -0.8438398178992906, 'e']], dtype=object)

# %% [markdown]
# ### シリーズ

# %% [markdown]
# コード11.2.8

# %%
s0 = df0["C0"]
s0
# Out:
# C3
# R0     3
# R1    17
# R2     5
# R3    49
# R4    26
# Name: C0, dtype: int64

# %% [markdown]
# コード11.2.9

# %%
s0.index
# Out:
# Index(['R0', 'R1', 'R2', 'R3', 'R4'], dtype='object', name='C3')

# %% [markdown]
# コード11.2.10

# %%
s0.to_numpy()
# Out:
# array([ 3, 17,  5, 49, 26])

# %% [markdown]
# ## データの抽出

# %% [markdown]
# ### データフレーム：一つの値を抽出する

# %% [markdown]
# コード11.3.1

# %%
df0.loc["R1", "C2"]
# Out:
# 'b'

# %% [markdown]
# コード11.3.2

# %%
df0.iloc[1, 2]
# Out:
# 'b'

# %% [markdown]
# コード11.3.3

# %%
random.seed(123)
n = 5
dic = {
    "C0":[random.randint(0,50) for _ in range(n)],
    "C1":[random.gauss() for _ in range(n)],
    "C2":["a", "b", "c", "d", "e"],
    "C3":["R"+str(i) for i in range(n)]
}
df0 = pd.DataFrame(dic)
print(df0)

df0.loc[1, "C2"]
# Out:
#    C0        C1 C2  C3
# 0   3 -0.198260  a  R0
# 1  17  1.899273  b  R1
# 2   5  0.689624  c  R2
# 3  49 -0.691135  d  R3
# 4  26 -0.843840  e  R4
# 'b'

# %% [markdown]
# ### データフレーム：スライシング

# %% [markdown]
# コード11.3.4

# %%
df = py4macro.data("data4")
df
# Out:
#              gdp     con     inv   pop continent
# country
# China      20118  7796.0  9137.0  1434      Asia
# France      2950  1598.0   806.0    67    Europe
# Germany     4274  2294.0   971.0    84    Europe
# India       9142  5936.0  2471.0  1366      Asia
# Italy       2463  1423.0   614.0    61    Europe
# Japan       5032  2675.0  1238.0   127      Asia
# Korea       2157   942.0   705.0    51      Asia
# Singapore    477   176.0   135.0     6      Asia
# Taiwan      1100   607.0     NaN    24      Asia
# UK          2994     NaN     NaN    68    Europe

# %% [markdown]
# コード11.3.5

# %%
df.loc["Germany":"Italy", "con":"pop"]
# Out:
#             con     inv   pop
# country
# Germany  2294.0   971.0    84
# India    5936.0  2471.0  1366
# Italy    1423.0   614.0    61

# %% [markdown]
# コード11.3.6

# %%
df.iloc[2:5, 1:4]
# df.iloc[2:4+1, 1:3+1]
# Out:
#             con     inv   pop
# country
# Germany  2294.0   971.0    84
# India    5936.0  2471.0  1366
# Italy    1423.0   614.0    61

# %% [markdown]
# ### データフレーム：リストを使う抽出方法

# %% [markdown]
# コード11.3.7

# %%
rows = ["UK", "Japan"]
cols = ["pop", "con"]
df.loc[rows,cols]
# Out:
#          pop     con
# country
# UK        68     NaN
# Japan    127  2675.0

# %% [markdown]
# コード11.3.8

# %%
df.iloc[[-1,5], [3,1]]
# Out:
#          pop     con
# country
# UK        68     NaN
# Japan    127  2675.0

# %% [markdown]
# ### データフレーム：10.2.3項の方法

# %% [markdown]
# ### データフレーム：3つの方法を駆使する

# %% [markdown]
# コード11.3.9

# %%
df.loc["Japan":"Taiwan", "gdp"]
# Out:
# country
# Japan        5032
# Korea        2157
# Singapore     477
# Taiwan       1100
# Name: gdp, dtype: int64

# %% [markdown]
# コード11.3.10

# %%
df.loc["Japan":"Taiwan",["gdp"]]
# Out:
#             gdp
# country
# Japan      5032
# Korea      2157
# Singapore   477
# Taiwan     1100

# %% [markdown]
# コード11.3.11

# %%
df.iloc[5:-1, 0]
# Out:
# country
# Japan        5032
# Korea        2157
# Singapore     477
# Taiwan       1100
# Name: gdp, dtype: int64

# %% [markdown]
# コード11.3.12

# %%
df.iloc[5:-1, [0]]
# Out:
#             gdp
# country
# Japan      5032
# Korea      2157
# Singapore   477
# Taiwan     1100

# %% [markdown]
# コード11.3.13

# %%
(
    df.loc["Japan":"Taiwan", "gdp"] /
    df.loc["Japan":"Taiwan", "pop"]
)
# Out:
# country
# Japan        39.622047
# Korea        42.294118
# Singapore    79.500000
# Taiwan       45.833333
# dtype: float64

# %% [markdown]
# コード11.3.14

# %%
(
    df.loc["Japan":"Taiwan", ["gdp"]] /
    df.loc["Japan":"Taiwan", ["pop"]]
)
# Out:
#            gdp  pop
# country
# Japan      NaN  NaN
# Korea      NaN  NaN
# Singapore  NaN  NaN
# Taiwan     NaN  NaN

# %% [markdown]
# ### シリーズ

# %% [markdown]
# コード11.3.15

# %%
s = df.loc[:,"gdp"]
s
# Out:
# country
# China        20118
# France        2950
# Germany       4274
# India         9142
# Italy         2463
# Japan         5032
# Korea         2157
# Singapore      477
# Taiwan        1100
# UK            2994
# Name: gdp, dtype: int64

# %% [markdown]
# コード11.3.16

# %%
print( s["Japan"] )
# Out:
# 5032

# %% [markdown]
# コード11.3.17

# %%
print( s.loc["Japan"] )
# Out:
# 5032

# %% [markdown]
# コード11.3.18

# %%
print( s.iloc[5] )
# Out:
# 5032

# %% [markdown]
# コード11.3.19

# %%
s.loc["Italy":"Korea"]
# s.iloc[4:-3]
# Out:
# country
# Italy    2463
# Japan    5032
# Korea    2157
# Name: gdp, dtype: int64

# %% [markdown]
# ### 条件に基づく行の抽出

# %% [markdown]
# #### 一つの条件の場合

# %% [markdown]
# コード11.3.20

# %%
df["continent"] == "Asia"
# Out:
# country
# China         True
# France       False
# Germany      False
# India         True
# Italy        False
# Japan         True
# Korea         True
# Singapore     True
# Taiwan        True
# UK           False
# Name: continent, dtype: bool

# %% [markdown]
# コード11.3.21

# %%
cond = ( df["continent"]=="Asia" )
df.loc[cond,:]
# Out:
#              gdp     con     inv   pop continent
# country
# China      20118  7796.0  9137.0  1434      Asia
# India       9142  5936.0  2471.0  1366      Asia
# Japan       5032  2675.0  1238.0   127      Asia
# Korea       2157   942.0   705.0    51      Asia
# Singapore    477   176.0   135.0     6      Asia
# Taiwan      1100   607.0     NaN    24      Asia

# %% [markdown]
# #### 複数条件の場合

# %% [markdown]
# コード11.3.22

# %%
cond1 = ( df["continent"] == "Asia" )
cond2 = ( df["gdp"] >= 4000 )
cond = cond1 & cond2
cond
# Out:
# country
# China         True
# France       False
# Germany      False
# India         True
# Italy        False
# Japan         True
# Korea        False
# Singapore    False
# Taiwan       False
# UK           False
# dtype: bool

# %% [markdown]
# コード11.3.23

# %%
df.loc[cond, ["gdp","con"]]
# Out:
#            gdp     con
# country
# China    20118  7796.0
# India     9142  5936.0
# Japan     5032  2675.0

# %% [markdown]
# コード11.3.24

# %%
cond1 = ( df["continent"] == "Asia" )
cond2 = ( df["gdp"] >= 4000 )
cond = cond1 | cond2
cond
# Out:
# country
# China         True
# France       False
# Germany       True
# India         True
# Italy        False
# Japan         True
# Korea         True
# Singapore     True
# Taiwan        True
# UK           False
# dtype: bool

# %% [markdown]
# コード11.3.25

# %%
df.loc[cond, ["gdp","con"]]
# Out:
#              gdp     con
# country
# China      20118  7796.0
# Germany     4274  2294.0
# India       9142  5936.0
# Japan       5032  2675.0
# Korea       2157   942.0
# Singapore    477   176.0
# Taiwan      1100   607.0

# %% [markdown]
# ## 欠損値の扱い

# %% [markdown]
# ### 欠損値の確認

# %% [markdown]
# コード11.4.1

# %%
df.isna()
# Out:
#              gdp    con    inv    pop  continent
# country
# China      False  False  False  False      False
# France     False  False  False  False      False
# Germany    False  False  False  False      False
# India      False  False  False  False      False
# Italy      False  False  False  False      False
# Japan      False  False  False  False      False
# Korea      False  False  False  False      False
# Singapore  False  False  False  False      False
# Taiwan     False  False   True  False      False
# UK         False   True   True  False      False

# %% [markdown]
# コード11.4.2

# %%
df.isna().sum()
# Out:
# gdp          0
# con          1
# inv          2
# pop          0
# continent    0
# dtype: int64

# %% [markdown]
# コード11.4.3

# %%
df.isna().sum(axis="columns")
# Out:
# country
# China        0
# France       0
# Germany      0
# India        0
# Italy        0
# Japan        0
# Korea        0
# Singapore    0
# Taiwan       1
# UK           2
# dtype: int64

# %% [markdown]
# ### 欠損値がある行・列の抽出

# %% [markdown]
# コード11.4.4

# %%
df.isna().any()
# Out:
# gdp          False
# con           True
# inv           True
# pop          False
# continent    False
# dtype: bool

# %% [markdown]
# コード11.4.5

# %%
df.isna().any(axis="columns")
# Out:
# country
# China        False
# France       False
# Germany      False
# India        False
# Italy        False
# Japan        False
# Korea        False
# Singapore    False
# Taiwan        True
# UK            True
# dtype: bool

# %% [markdown]
# コード11.4.6

# %%
cond = df.isna().any(axis="columns")
df.loc[cond,:]
# Out:
#           gdp    con  inv  pop continent
# country
# Taiwan   1100  607.0  NaN   24      Asia
# UK       2994    NaN  NaN   68    Europe

# %% [markdown]
# ### 欠損値がある行の削除

# %% [markdown]
# コード11.4.7

# %%
df.dropna()
# Out:
#              gdp     con     inv   pop continent
# country
# China      20118  7796.0  9137.0  1434      Asia
# France      2950  1598.0   806.0    67    Europe
# Germany     4274  2294.0   971.0    84    Europe
# India       9142  5936.0  2471.0  1366      Asia
# Italy       2463  1423.0   614.0    61    Europe
# Japan       5032  2675.0  1238.0   127      Asia
# Korea       2157   942.0   705.0    51      Asia
# Singapore    477   176.0   135.0     6      Asia

# %% [markdown]
# コード11.4.8

# %%
df.dropna(subset=["con"])
# Out:
#              gdp     con     inv   pop continent
# country
# China      20118  7796.0  9137.0  1434      Asia
# France      2950  1598.0   806.0    67    Europe
# Germany     4274  2294.0   971.0    84    Europe
# India       9142  5936.0  2471.0  1366      Asia
# Italy       2463  1423.0   614.0    61    Europe
# Japan       5032  2675.0  1238.0   127      Asia
# Korea       2157   942.0   705.0    51      Asia
# Singapore    477   176.0   135.0     6      Asia
# Taiwan      1100   607.0     NaN    24      Asia
