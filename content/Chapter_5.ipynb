# %% [markdown]
# # 第5章：オブジェクトと属性

# %% [markdown]
# ## オブジェクト

# %% [markdown]
# ### オブジェクトとは

# %% [markdown]
# ### 属性とメソッドの調べ方

# %% [markdown]
# コード5.1.1

# %%
x = 3.14
dir(x)
# Out:
# ['__abs__',
#  '__add__',
#  '__bool__',
#  '__ceil__',
#  '__class__',
#  '__delattr__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floor__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getformat__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__le__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmod__',
#  '__rmul__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__trunc__',
#  'as_integer_ratio',
#  'conjugate',
#  'fromhex',
#  'hex',
#  'imag',
#  'is_integer',
#  'real']

# %% [markdown]
# コード5.1.2

# %%
type(x)
# Out:
# float

# %% [markdown]
# コード5.1.3

# %%
x.__class__
# Out:
# float

# %% [markdown]
# ## メソッド

# %% [markdown]
# ### リスト

# %% [markdown]
# コード5.2.1

# %%
lst = [2.1, 5, 5]
lst.append(3)

# %% [markdown]
# コード5.2.2

# %%
lst = [2.1, 5, 5]
lst = lst + [3]
lst

# %% [markdown]
# 表5.1

# %%
lst = [2.1, 5, 5]
lst.append(3)
lst.clear()
lst
# Out:
# []

# %% [markdown]
# 表5.1

# %%
lst = [2.1, 5, 5]
lst.append(3)
lst.copy()
lst
# Out:
# [2.1, 5, 5, 3]

# %% [markdown]
# 表5.1

# %%
lst = [2.1, 5, 5]
lst.append(3)
lst.count(5)
# Out:
# 2

# %% [markdown]
# 表5.1

# %%
lst = [2.1, 5, 5]
lst.append(3)
lst.extend([0, 1])
lst
# Out:
# [2.1, 5, 5, 3, 0, 1]

# %% [markdown]
# 表5.1

# %%
lst = [2.1, 5, 5]
lst.append(3)
lst.index(5)
# Out:
# 1

# %% [markdown]
# 表5.1

# %%
lst = [2.1, 5, 5]
lst.append(3)
lst.insert(1, 10)
lst
# Out:
# [2.1, 10, 5, 5, 3]

# %% [markdown]
# 表5.1

# %%
lst = [2.1, 5, 5]
lst.append(3)
lst.pop(0)
lst
# Out:
# [5, 5, 3]

# %% [markdown]
# 表5.1

# %%
lst = [2.1, 5, 5]
lst.append(3)
lst.remove(5)
lst
# Out:
# [2.1, 5, 3]

# %% [markdown]
# 表5.1

# %%
lst = [2.1, 5, 5]
lst.append(3)
lst.reverse()
lst
# Out:
# [3, 5, 5, 2.1]

# %% [markdown]
# 表5.1

# %%
lst = [2.1, 5, 5]
lst.append(3)
lst.sort()
lst
# Out:
# [2.1, 3, 5, 5]

# %% [markdown]
# 表5.1

# %%
lst = [2.1, 5, 5]
lst.append(3)
lst.sort(reverse=True)
lst
# Out:
# [5, 5, 3, 2.1]

# %% [markdown]
# ### 辞書

# %% [markdown]
# コード5.2.3

# %%
dct = {"GDP":592, "消費":323}
dct.items()
# Out:
# dict_items([('GDP', 592), ('消費', 323)])

# %% [markdown]
# コード5.2.4

# %%
list( dct.items() )
# Out:
# [('GDP', 592), ('消費', 323)]

# %% [markdown]
# 表5.2

# %%
dct = {"GDP":592, "消費":323}
dct.clear()
dct
# Out:
# {}

# %% [markdown]
# 表5.2

# %%
dct = {"GDP":592, "消費":323}
dct.copy()
dct
# Out:
# {'GDP': 592, '消費': 323}

# %% [markdown]
# 表5.2

# %%
dct = {"GDP":592, "消費":323}
dct.get("消費")
# Out:
# 323

# %% [markdown]
# 表5.2

# %%
dct = {"GDP":592, "消費":323}
dct.get("純輸出")

# %% [markdown]
# 表5.2

# %%
dct = {"GDP":592, "消費":323}
dct.get("純輸出", 10)
# Out:
# 10

# %% [markdown]
# 表5.2

# %%
dct = {"GDP":592, "消費":323}
dct.keys()
# Out:
# dict_keys(['GDP', '消費'])

# %% [markdown]
# 表5.2

# %%
dct = {"GDP":592, "消費":323}
dct.pop("消費")
dct
# Out:
# {'GDP': 592}

# %% [markdown]
# 表5.2

# %%
dct = {"GDP":592, "消費":323}
dct.values()
# Out:
# dict_values([592, 323])

# %% [markdown]
# 表5.2

# %% [markdown]
# ### 文字列

# %% [markdown]
# コード5.2.5

# %%
s = "python is FUN!  "

# %% [markdown]
# 表5.3

# %%
s.capitalize()
# Out:
# 'Python is fun!  '

# %% [markdown]
# 表5.3

# %%
s.center(20, "*")
# Out:
# '**python is FUN!  **'

# %% [markdown]
# 表5.3

# %%
s.lower()
# Out:
# 'python is fun!  '

# %% [markdown]
# 表5.3

# %%
s.replace(" ", "-")
# Out:
# 'python-is-FUN!--'

# %% [markdown]
# 表5.3

# %%
s.split()
# Out:
# ['python', 'is', 'FUN!']

# %% [markdown]
# 表5.3

# %%
s.strip()
# Out:
# 'python is FUN!'

# %% [markdown]
# 表5.3

# %%
s.title()
# Out:
# 'Python Is Fun!  '

# %% [markdown]
# 表5.3

# %%
s.upper()
# Out:
# 'PYTHON IS FUN!  '

# %% [markdown]
# ### メソッドチェーン

# %% [markdown]
# コード5.2.6

# %%
s.strip().upper().replace(" ", "-")
# Out:
# 'PYTHON-IS-FUN!'
