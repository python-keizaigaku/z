# %% [markdown]
# # 第3章：コンテナデータ型とその操作

# %% [markdown]
# ## 4つのコンテナデータ型

# %% [markdown]
# ### リストとタプル

# %% [markdown]
# コード3.1.1

# %%
lst = [10, True, "国内総生産"]

# %% [markdown]
# コード3.1.2

# %%
tpl = (10, True, "国内総生産")

# %% [markdown]
# コード3.1.3

# %%
tpl = 10, True, "国内総生産"

# %% [markdown]
# コード3.1.4

# %%
t0, t1, t2 = 10, True, "国内総生産"

# %% [markdown]
# ### 辞書と集合

# %% [markdown]
# コード3.1.5

# %%
{10, 10, 10, True, True, True, 4, "Kobe", "Kobe"}
# Out:
# {10, 4, 'Kobe', True}

# %% [markdown]
# コード3.1.6

# %%
dct = {"GDP":557, "消費":298, "投資":111}

# %% [markdown]
# ## コンテナデータ型の操作

# %% [markdown]
# ### リストとタプル：要素のアクセス

# %% [markdown]
# コード3.2.1

# %%
abc = ["A", "B", "C", "D", "E", "F"]

# %% [markdown]
# コード3.2.2

# %%
abc[2]
# Out:
# 'C'

# %% [markdown]
# コード3.2.3

# %%
lst0 = [["GDP",557], ["消費",298], ["投資",111]]
lst0[-1][0]
# Out:
# '投資'

# %% [markdown]
# コード3.2.4

# %%
lst0_last = lst0[-1]
lst0_last[0]
# Out:
# '投資'

# %% [markdown]
# コード3.2.5

# %%
tpl = (10, True, "国内総生産")
tpl[1]
# Out:
# True

# %% [markdown]
# ### リストとタプル：要素のスライシング

# %% [markdown]
# 例3.2(a)

# %%
abc[1:4]
# Out:
# ['B', 'C', 'D']

# %% [markdown]
# 例3.2(b)

# %%
abc[1:3+1]
# Out:
# ['B', 'C', 'D']

# %% [markdown]
# 例3.2(c)

# %%
abc[:3]
# Out:
# ['A', 'B', 'C']

# %% [markdown]
# 例3.2(d)

# %%
abc[3:]
# Out:
# ['D', 'E', 'F']

# %% [markdown]
# 例3.2(e)

# %%
abc[3:-1]
# Out:
# ['D', 'E']

# %% [markdown]
# ### 辞書

# %% [markdown]
# 例3.3(a)

# %%
dct["GDP"]
# Out:
# 557

# %% [markdown]
# 例3.3(b)

# %%
dct["消費"]
# Out:
# 298

# %% [markdown]
# 例3.3(c)

# %%
dct["投資"]
# Out:
# 111

# %% [markdown]
# ### 要素の更新

# %% [markdown]
# コード3.2.6

# %%
abc[2] = 100
abc
# Out:
# ['A', 'B', 100, 'D', 'E', 'F']

# %% [markdown]
# コード3.2.7

# %%
dct["投資"] = 200
dct
# Out:
# {'GDP': 557, '消費': 298, '投資': 200}

# %% [markdown]
# ### 要素の削除

# %% [markdown]
# コード3.2.8

# %%
del abc[0]
abc
# Out:
# ['B', 100, 'D', 'E', 'F']

# %% [markdown]
# コード3.2.9

# %%
del dct["GDP"]
dct
# Out:
# {'消費': 298, '投資': 200}

# %% [markdown]
# ### 要素の追加

# %% [markdown]
# コード3.2.10

# %%
lst1 = ["消費", "投資"]
lst1.append("政府支出")
lst1
# Out:
# ['消費', '投資', '政府支出']

# %% [markdown]
# コード3.2.11

# %%
dct["政府支出"] = 145
dct
# Out:
# {'消費': 298, '投資': 200, '政府支出': 145}

# %% [markdown]
# コード3.2.12

# %%
dct.update(輸出=113, 輸入=110)
dct
# Out:
# {'消費': 298, '投資': 200, '政府支出': 145, '輸出': 113, '輸入': 110}

# %% [markdown]
# ## 関連トピック

# %% [markdown]
# ### リストとタプル：連結

# %% [markdown]
# コード3.3.1

# %%
lst2 = ["C", "I"]
lst3 = lst2 + ["G", "NX"]
lst2, lst3
# Out:
# (['C', 'I'], ['C', 'I', 'G', 'NX'])

# %% [markdown]
# コード3.3.2

# %%
("C", "I") + ("G", "NX")
# Out:
# ('C', 'I', 'G', 'NX')

# %% [markdown]
# コード3.3.3

# %%
[0] * 5
# Out:
# [0, 0, 0, 0, 0]

# %% [markdown]
# ### 辞書：結合

# %% [markdown]
# コード3.3.4

# %%
{"輸出":113} | {"輸入":110}
# Out:
# {'輸出': 113, '輸入': 110}

# %% [markdown]
# コード3.3.5

# %%
{"輸出":113, "輸入":110} | {"輸入":0}
# Out:
# {'輸出': 113, '輸入': 0}

# %% [markdown]
# ### 文字列からの文字抽出

# %% [markdown]
# コード3.3.6

# %%
moji = "economics"

# %% [markdown]
# 例3.4(a)

# %%
moji[1:4]
# Out:
# 'con'

# %% [markdown]
# 例3.4(b)

# %%
moji[1:3+1]
# Out:
# 'con'

# %% [markdown]
# 例3.4(c)

# %%
moji[:3]
# Out:
# 'eco'

# %% [markdown]
# 例3.4(d)

# %%
moji[3:]
# Out:
# 'nomics'

# %% [markdown]
# 例3.4(e)

# %%
moji[3:-1]
# Out:
# 'nomic'

# %% [markdown]
# 例3.4(f)

# %%
"Macro" + moji
# Out:
# 'Macroeconomics'

# %% [markdown]
# 例3.4(g)

# %%
"(^o^)/" * 3
# Out:
# '(^o^)/(^o^)/(^o^)/'

# %% [markdown]
# ### 改行

# %% [markdown]
# コード3.3.7

# %%
long_variable_name_1 = 10
long_variable_name_2 = 20

(
  long_variable_name_1 +
  long_variable_name_2
)
# Out:
# 30

# %% [markdown]
# コード3.3.8

# %%
my_lst = ["消費",
          "投資",
          "政府支出"]

# %% [markdown]
# コード3.3.9

# %%
my_dct = {"消費":298,
          "投資":113,
          "a":[1,2]}

# %% [markdown]
# ### 所属演算子

# %% [markdown]
# コード3.3.10

# %%
"消費" in my_lst
# Out:
# True

# %% [markdown]
# コード3.3.11

# %%
"純輸出" in my_dct
# Out:
# False
