# %% [markdown]
# # 第7章: ライブラリとエラーの基本

# %% [markdown]
# ## ライブラリ

# %% [markdown]
# モジュール・パッケージ・ライブラリとは

# %% [markdown]
# ### NumPyライブラリ

# %% [markdown]
# コード7.1.1

# %%
import numpy
print( numpy.log(10) )
# Out:
# 2.302585092994046

# %% [markdown]
# コード7.1.2

# %%
import numpy as np
print( np.log(10) )
# Out:
# 2.302585092994046

# %% [markdown]
# コード7.1.3

# %%
from numpy import log
print( log(10) )
# Out:
# 2.302585092994046

# %% [markdown]
# コード7.1.4

# %%
# np.linalg.solve()

# %% [markdown]
# コード7.1.5

# %%
from numpy import linalg as AL
# AL.solve()

# %% [markdown]
# 表7.1

# %%
print( np.log10(10) )
# Out:
# 1.0

# %% [markdown]
# 表7.1

# %%
print( np.log(10) )
# Out:
# 2.302585092994046

# %% [markdown]
# 表7.1

# %%
print( np.exp(1) )
# Out:
# 2.718281828459045

# %% [markdown]
# 表7.1

# %%
print( np.sqrt(4) )
# Out:
# 2.0

# %% [markdown]
# ### randomモジュール

# %% [markdown]
# コード7.1.6

# %%
import random

# %% [markdown]
# コード7.1.7

# %%
random.randint(1, 6)
# Out:
# 4

# %% [markdown]
# コード7.1.8

# %%
lst = []

for _ in range(5):
    val = random.randint(1,6)
    lst.append(val)

# %% [markdown]
# コード7.1.9

# %%
[random.randint(1,6) for _ in range(5)]
# Out:
# [6, 5, 3, 2, 6]

# %% [markdown]
# コード7.1.10

# %%
random.gauss()
# Out:
# -1.0789375951614912

# %% [markdown]
# コード7.1.11

# %%
[random.gauss(0,10) for _ in range(5)]
# Out:
# [-11.157892150722322,
#  12.020887611527593,
#  1.2762392793335446,
#  -3.503633113270686,
#  -0.04476227379274461]

# %% [markdown]
# コード7.1.12

# %%
random.seed(123)
[random.gauss(0,10) for _ in range(4)]
# Out:
# [4.042284332246665, 1.380113926483041, -3.985847224936054, 2.6274798902660246]

# %% [markdown]
# ### py4macroモジュール

# %% [markdown]
# コード7.1.13

# %%
# %pip install -q py4macro
import py4macro
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 20.0 MB/s eta 0:00:00

# %% [markdown]
# コード7.1.14

# %%
py4macro.xvalues(0, 1, 3)
# Out:
# [0.0, 0.5, 1.0]

# %% [markdown]
# コード7.1.15

# %%
pi = 3.14
py4macro.see(pi)
# Out:
# .as_integer_ratio()  .conjugate()         .fromhex()           .hex()
# .imag                .is_integer()        .real

# %% [markdown]
# ## エラー

# %% [markdown]
# ### 構文エラー

# %% [markdown]
# 構文エラー：例1

# %%
if a > 0
    print(a)
# Out:
#   File "/tmp/ipython-input-21-2054018969.py", line 1
#     if a > 0
#             ^
# SyntaxError: expected ':'

# %% [markdown]
# 構文エラー：例2

# %%
2 / (10.1 + 3.2 + 1
# Out:
#   File "/tmp/ipython-input-22-3427217829.py", line 1
#     2 / (10.1 + 3.2 + 1
#                        ^
# SyntaxError: incomplete input

# %% [markdown]
# 構文エラー：例3

# %%
def my_func(a):
return a * 2
# Out:
#   File "/tmp/ipython-input-23-2010791606.py", line 2
#     return a * 2
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %% [markdown]
# ### 例外

# %% [markdown]
# 例外：例1

# %%
3 + 1 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-24-1744901223.py in <cell line: 0>()
# ----> 1 3 + 1 / 0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# 例外：例2

# %%
1.5 + yy * 2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-25-2269338910.py in <cell line: 0>()
# ----> 1 1.5 + yy * 2
#
# NameError: name 'yy' is not defined

# %% [markdown]
# 例外：例3

# %%
10 + "3"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-26-493632504.py in <cell line: 0>()
# ----> 1 10 + "3"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
