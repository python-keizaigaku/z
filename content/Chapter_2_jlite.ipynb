# %% [markdown]
# # 第2章：Pythonの基礎

# %% [markdown]
# ## 4つの基本データ型

# %% [markdown]
# コード2.1.1

# %%
557_000_000_000_000
# Out:
# 557000000000000

# %% [markdown]
# 例2.2(a)

# %%
3.14
# Out:
# 3.14

# %% [markdown]
# 例2.2(b)

# %%
314159.2
# Out:
# 314159.2

# %% [markdown]
# 例2.2(c)

# %%
0.0000314
# Out:
# 3.14e-05

# %% [markdown]
# 例2.2(d)

# %%
0.0
# Out:
# 0.0

# %% [markdown]
# 例2.2(e)

# %%
3.141592e+05
# Out:
# 314159.2

# %% [markdown]
# 例2.2(f)

# %%
3.141592e-05
# Out:
# 3.141592e-05

# %% [markdown]
# コード2.1.2

# %%
0.0000314
# Out:
# 3.14e-05

# %% [markdown]
# コード2.1.3

# %%
557e+12
# Out:
# 557000000000000.0

# %% [markdown]
# コード2.1.4

# %%
"He said 'GDP is 557 trillion yen!' and similed."
# Out:
# "He said 'GDP is 557 trillion yen!' and similed."

# %% [markdown]
# ## 演算子

# %% [markdown]
# ### 算術演算子

# %% [markdown]
# ### 比較演算子

# %% [markdown]
# コード2.2.1

# %%
2 == True + True + False
# Out:
# True

# %% [markdown]
# コード2.2.2

# %%
"Python" != "python"
# Out:
# True

# %% [markdown]
# ### ブール演算子

# %% [markdown]
# コード2.2.3

# %%
not ( 0 > 1 )
# Out:
# True

# %% [markdown]
# コード2.2.4

# %%
( 1 > 0 ) and ( -1 > 0 )
# Out:
# False

# %% [markdown]
# ## 演算子の優先順位

# %% [markdown]
# コード2.3.1

# %%
2 + 3 ** 2
# Out:
# 11

# %% [markdown]
# コード2.3.2

# %%
3 * 2 < 10
# Out:
# True

# %% [markdown]
# コード2.3.3

# %%
not True and False
# Out:
# False

# %% [markdown]
# コード2.3.4

# %%
3 == 3 or False
# Out:
# True

# %% [markdown]
# コード2.3.5

# %%
3 + 2 ** 2 > 5 and True
# Out:
# True

# %% [markdown]
# コード2.3.6

# %%
- 3 ** 2
# Out:
# -9

# %% [markdown]
# コード2.3.7

# %%
( - 3 ) ** 2
# Out:
# 9

# %% [markdown]
# コード2.3.8

# %%
- 3 - 5
# Out:
# -8

# %% [markdown]
# コード2.3.9

# %%
- ( 3 - 5 )
# Out:
# 2

# %% [markdown]
# コード2.3.10

# %%
2 ** 3 ** 2
# 2 ** (3 ** 2)
# Out:
# 512

# %% [markdown]
# コード2.3.11

# %%
8 / 4 * 2
# ( 8 / 4 ) * 2
# Out:
# 4.0

# %% [markdown]
# コード2.3.12

# %%
5 < 10 == True
# (5 < 10) and (10 == True)
# Out:
# False

# %% [markdown]
# コード2.3.13

# %%
not not False
# not (not False)
# Out:
# False

# %% [markdown]
# コード2.3.14

# %%
True and False and True
# (True and False) and True
# Out:
# False

# %% [markdown]
# ## 変数への代入

# %% [markdown]
# ### 代入演算子

# %% [markdown]
# コード2.4.1

# %%
x = 10
x + x / 2
# Out:
# 15.0

# %% [markdown]
# コード2.4.2

# %%
x = 10
x = x + 1
x
# Out:
# 11

# %% [markdown]
# ### 複合代入演算子

# %% [markdown]
# コード2.4.3

# %%
x += 1

# %% [markdown]
# コード2.4.4

# %%
y = 100
y /= 2
y
# Out:
# 50.0

# %% [markdown]
# 表2.2

# %%
x = 10
x += 1
x
# Out:
# 11

# %% [markdown]
# 表2.2

# %%
x = 10
x -= 1
x
# Out:
# 9

# %% [markdown]
# 表2.2

# %%
x = 10
x *= 2
x
# Out:
# 20

# %% [markdown]
# 表2.2

# %%
x = 10
x /= 2
x
# Out:
# 5.0

# %% [markdown]
# 表2.2

# %%
x = 10
x **= 2
x
# Out:
# 100

# %% [markdown]
# 表2.2

# %%
x = 10
x //= 3
x
# Out:
# 3

# %% [markdown]
# 表2.2

# %%
x = 10
x %= 3
x
# Out:
# 1

# %% [markdown]
# ### 変数名

# %% [markdown]
# ## コメント

# %% [markdown]
# コード2.5.1

# %%
inflation = 0.02   # インフレ率

# %% [markdown]
# コード2.5.2

# %%
x = 10
# x += 5
x
# Out:
# 10
